# %% [markdown]
# This cell just imports all the necessary packages.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('resultsNew fewShot100 model modelspcnn_lr:0.00020_nr-resnet5_nr-filters160_339.pth.csv',header=None,names=["Epoch","Train","Test","Constant","Low-Variance","SVHN"])

# %%
df=pd.read_csv('glow_results.csv',header=None,names=["Train","Test","Constant","Low-Variance","SVHN"])

# %%
arr=["Train","Test","Constant","Low-Variance","SVHN"]

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df_512=pd.read_csv('glow_results_hiddenlayers256.csv',header=None,names=["Train","Test","Constant","Low-Variance","SVHN"])

# %%
df_512.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
