# %% [markdown]
# This cell just imports all the necessary packages.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('resultsNew.csv',header=None,names=["Epoch","Train","Test","Constant","Low-Variance","SVHN"])

# %%
arr=["Epoch","Train","Test","Constant","Low-Variance","SVHN"]

# %%
df.plot(x='Epoch',y=arr[1:])
# Out:
# <img src="data:image/png;base64,..." width="640">
