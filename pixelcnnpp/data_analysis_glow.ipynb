# %% [markdown]
# This cell just imports all the necessary packages.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('resultsNew fewShot100 model modelspcnn_lr:0.00020_nr-resnet5_nr-filters160_339.pth.csv',header=None,names=["Epoch","Train","Test","Constant","Low-Variance","SVHN"])

# %%
arr=["Epoch","Train","Test","Constant","Low-Variance","SVHN"]

# %%
df.plot(x='Epoch',y=arr[1:])
# Out:
# <img src="data:image/png;base64,..." width="640">
