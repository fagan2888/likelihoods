# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("simple_models.csv")
slope=(df.iloc[-1,1]-df.iloc[-2,1])/(df.iloc[-1,0]-df.iloc[-2,0])
xPoint=df.iloc[-1,0]
yPoint=df.iloc[-1,1]
df.plot(0,1)
#plt.plot(df.iloc[:,0],df.iloc[:,1])
#plt.plot(np.linspace(0,500,500),yPoint+(np.linspace(0,500,500)-xPoint)*slope,'r')
print(slope)
# Out:
# 0.012819257157401669

# %%
df.iloc[df.idxmin(axis=0)[1], 1]
# Out:
# 2.822930097579956
